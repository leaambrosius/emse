# %%
import numpy as np
import pandas as pd
import sm as sm
import pandas as pd
import statsmodels.api as sm
from matplotlib import pyplot as plt
from scipy import stats
import plotly.express as px
import numpy as np

data = pd.read_csv("data_arunge.csv")
data1 = pd.read_csv("data_arunge.csv")
data.describe()
# Out:
#        Unnamed: 0  Ihr Alter in Jahren:  Amotivation  External Regulation  \
# count  107.000000            107.000000   107.000000           107.000000
# mean    55.560748             27.467290     1.892523             2.039720
# std     32.591288             11.172167     0.475970             0.713044
# min      0.000000             17.000000     1.000000             1.000000
# 25%     27.500000             23.000000     1.500000             1.500000
# 50%     56.000000             24.000000     1.750000             2.000000
# 75%     83.500000             27.000000     2.250000             2.500000
# max    112.000000             85.000000     3.250000             4.000000
#
#        Introjected Regulation  Identified Regulation  Integrated Regulation  \
# count              107.000000             107.000000             107.000000
# mean                 3.747664               3.102804               3.815421
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[49], line 5
#       3 i = 0
#       4 for i in range(107):
# ----> 5     motivationScore = (data.iloc[i,11] +data.iloc[i,14] + data.iloc[i,20] +data.iloc[i,27]) /4
#       6     motivationScoreArray.append(motivationScore)
#       7 data["Motivation Score"] = motivationScoreArray
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:1096, in _LocationIndexer.__getitem__(self, key)
#    1094     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1095     if self._is_scalar_access(key):
# -> 1096         return self.obj._get_value(*key, takeable=self._takeable)
#    1097     return self._getitem_tuple(key)
#    1098 else:
#    1099     # we by definition only have the 0th axis
#
# ...

# %%
#del data['Ihr Alter in Jahren:']
del data['Wie häufig machen Sie in der Woche Sport?']
del data['Motiviert es Sie, wenn Sie Ihre Leistungen mit denen Ihrer Freunde vergleichen?  ']
del data['Glauben Sie, dass Sie Ihre Sportlichen Ziele durch Benutzung einer Sport-App effizienter erreichen können? ']
del data['Wofür benutzen Sie Sport-Apps? (mehrere Antworten möglich)  ']
del data['Wie oft benutzen Sie eine Sport-App?  ']
del data['Welche Sportarten machen Sie? (mehrere Antworten möglich)']
#gruppiert = data.groupby(["Haben Sie schonmal Sport-Apps genutzt? (Z.B. Apple Sports, Adidas Running App, Komoot, Nike Training Club, Freeletics, Urban Sports Club, Stava, etc.)  ","Geschlecht"]).mean()
#gruppiert
data
# Out:
#      Unnamed: 0 Geschlecht  Ihr Alter in Jahren:  \
# 0             0   Weiblich                    22
# 1             1   Weiblich                    23
# 2             2   Weiblich                    25
# 3             3   Weiblich                    18
# 4             4   Weiblich                    18
# ..          ...        ...                   ...
# 102         107   Weiblich                    31
# 103         108   Weiblich                    65
# 104         110   Weiblich                    64
# 105         111   Männlich                    24
# 106         112   Weiblich                    26
#
#     Haben Sie schonmal Sport-Apps genutzt? (Z.B. Apple Sports, Adidas Running App, Komoot, Nike Training Club, Freeletics, Urban Sports Club, Stava, etc.)    \
# 0                                                   Ja
# 1                                                   Ja
# 2                                                   Ja
# ...

# %%
# Out:
# 3.0

# %%
data
# calculate Motivation Score
motivationScoreArray = []
i = 0
for i in range(107):
    motivationScore = (1*data.iloc[i,4] +2*data.iloc[i,5] + 3*data.iloc[i,6] +4*data.iloc[i,7]+5*data.iloc[i,8]+6*data.iloc[i,9])/21
    motivationScoreArray.append(motivationScore)
data["Motivation Score"] = motivationScoreArray
data1["Motivation Score"] = motivationScoreArray
data
# Out:
#      Unnamed: 0 Geschlecht  Ihr Alter in Jahren:  \
# 0             0   Weiblich                    22
# 1             1   Weiblich                    23
# 2             2   Weiblich                    25
# 3             3   Weiblich                    18
# 4             4   Weiblich                    18
# ..          ...        ...                   ...
# 102         107   Weiblich                    31
# 103         108   Weiblich                    65
# 104         110   Weiblich                    64
# 105         111   Männlich                    24
# 106         112   Weiblich                    26
#
#     Haben Sie schonmal Sport-Apps genutzt? (Z.B. Apple Sports, Adidas Running App, Komoot, Nike Training Club, Freeletics, Urban Sports Club, Stava, etc.)    \
# 0                                                   Ja
# 1                                                   Ja
# 2                                                   Ja
# ...

# %%
gruppiert = data.groupby(["Haben Sie schonmal Sport-Apps genutzt? (Z.B. Apple Sports, Adidas Running App, Komoot, Nike Training Club, Freeletics, Urban Sports Club, Stava, etc.)  ","Geschlecht"]).mean()
gruppiert
# Out:
#                                                                  Unnamed: 0  \
# Haben Sie schonmal Sport-Apps genutzt? (Z.B. Ap... Geschlecht
# Ja                                                 Keine Angabe   66.000000
#                                                    Männlich       66.431818
#                                                    Weiblich       46.468085
# Nein                                               Männlich       65.800000
#                                                    Weiblich       44.300000
#
#                                                                  Ihr Alter in Jahren:  \
# Haben Sie schonmal Sport-Apps genutzt? (Z.B. Ap... Geschlecht
# Ja                                                 Keine Angabe             25.000000
#                                                    Männlich                 26.954545
#                                                    Weiblich                 25.319149
# ...

# %%
median = data1['Amotivation'].median()
print('Median Amotivation: {:.3f}'.format(median))
median = data1['Ihr Alter in Jahren:'].median()
print('Median Age: {:.3f}'.format(median))
median = data1['External Regulation'].median()
print('Median External Regulation: {:.3f}'.format(median))
median = data1['Integrated Regulation'].median()
print('Median Integrated Regulation: {:.3f}'.format(median))
median = data1['Intrinsic Motivation'].median()
print('Median Intrinsic Motivation: {:.3f}'.format(median))
median = data1['Introjected Regulation'].median()
print('Median Introjected Regulation: {:.3f}'.format(median))
median = data1['Identified Regulation'].median()
print('Median Identified Regulation: {:.3f}'.format(median))
# Out:
# Median Amotivation: 1.750
# Median Age: 24.000
# Median External Regulation: 2.000
# Median Integrated Regulation: 4.000
# Median Intrinsic Motivation: 3.750
# Median Introjected Regulation: 3.750
# Median Identified Regulation: 3.000

# %%
mean = data1['Amotivation'].mean()
print('Mean Amotivation: {:.3f}'.format(mean))
mean = data1['Ihr Alter in Jahren:'].mean()
print('Mean Age: {:.3f}'.format(mean))
mean = data1['External Regulation'].mean()
print('Mean External Regulation: {:.3f}'.format(mean))
mean = data1['Integrated Regulation'].mean()
print('Mean Integrated Regulation: {:.3f}'.format(mean))
mean = data1['Intrinsic Motivation'].mean()
print('Mean Intrinsic Motivation: {:.3f}'.format(mean))
mean = data1['Introjected Regulation'].mean()
print('Mean Introjected Regulation: {:.3f}'.format(median))
mean = data1['Identified Regulation'].mean()
print('Mean Identified Regulation: {:.3f}'.format(mean))
# Out:
# Mean Amotivation: 1.893
# Mean Age: 27.467
# Mean External Regulation: 2.040
# Mean Integrated Regulation: 3.815
# Mean Intrinsic Motivation: 3.685
# Mean Introjected Regulation: 3.000
# Mean Identified Regulation: 3.103

# %%
mode = data1['Wie häufig machen Sie in der Woche Sport?'].mode()
count_mode = data['Wie häufig machen Sie in der Woche Sport?'].value_counts()[mode]
print('mode:', mode[0])
print('mode and number of time is has repeated are: ', count_mode)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Wie häufig machen Sie in der Woche Sport?'
#
# ...

# %%
Q1 = data1['Amotivation'].quantile(0.25)
Q3 = data1['Amotivation'].quantile(0.75)
# Q1 returns the first quartile of the data, which is the value below which 25% of the data falls


# filter the data to include only values within the interquartile range
iqr_data = data[(data1['Amotivation'] >= Q1) & (data1['Amotivation'] <= Q3)]['Amotivation']

# calculate the mode of the filtered data
mode = iqr_data.mode()[0]

inq_range=Q3-Q1
print('The mode within the interquartile range ({:.2f} - {:.2f}) is: {}'.format(Q1, Q3,mode))
print('inq range:',inq_range )
# Out:
# The mode within the interquartile range (1.50 - 2.25) is: 1.75
# inq range: 0.75

# %%
variance = data1['Amotivation'].var()
print('variance Amotivation: {:.3f}'.format(variance))
variance_by_language = data1.groupby('Wie häufig machen Sie in der Woche Sport?')['Amotivation'].var()

for lang, var in variance_by_language.items():
    print("Variance of (Wie häufig machen Sie Sport in der Woche?) {} = {:.3f}".format(lang, var))
# Out:
# variance Amotivation: 0.227
# Variance of (Wie häufig machen Sie Sport in der Woche?) 1-2 mal die Woche = 0.283
# Variance of (Wie häufig machen Sie Sport in der Woche?) 3-4 mal die Woche = 0.220
# Variance of (Wie häufig machen Sie Sport in der Woche?) 5-6 mal die Woche = 0.189
# Variance of (Wie häufig machen Sie Sport in der Woche?) Jeden Tag = 0.021

# %%
stdev = data1['Amotivation'].std()
print('stdev Amotivation: {:.3f}'.format(stdev))
# Out:
# stdev Amotivation: 0.476

# %%
stdev_by_language = data1.groupby('Wie häufig machen Sie in der Woche Sport?')['Amotivation'].std()

for lang, var in stdev_by_language.items():
    print("SD of (Wie häufig machen Sie in der Woche Sport?) {} = {:.2f}".format(lang, var))
# Out:
# SD of (Wie häufig machen Sie in der Woche Sport?) 1-2 mal die Woche = 0.53
# SD of (Wie häufig machen Sie in der Woche Sport?) 3-4 mal die Woche = 0.47
# SD of (Wie häufig machen Sie in der Woche Sport?) 5-6 mal die Woche = 0.44
# SD of (Wie häufig machen Sie in der Woche Sport?) Jeden Tag = 0.14

# %%
skew = data1['Amotivation'].skew()
print('skew Amotivation: {:.3f}'.format(skew))
# Out:
# skew Amotivation: 0.663

# %%
kurtosis = data1['Amotivation'].kurtosis()
print('Kurtosis: {:.3f}'.format(kurtosis))
# Out:
# Kurtosis: 0.151

# %%
from matplotlib import pyplot as plt

data1.hist(column='Amotivation',color='skyblue', edgecolor='black', linewidth=1, alpha=0.8, zorder=2)
plt.grid(linestyle='dashed',alpha=0.5)


data1.hist(column='Amotivation')


plt.ylabel('Frequency')


#plt.title('Histogram of Language Distribution')


### We also can set custom labels for the x-axis

labels = ['1-2', '3-4', '5-6', 'über 6']
#plt.xticks(range(1, 4), labels)


plt.show()

# %%
# Bin=5
data1.hist(column='Amotivation',color='orange',edgecolor='black', linewidth=1, alpha=0.7, zorder=2,bins=5)
plt.grid(linestyle='--', alpha=0.3)
plt.ylabel('Frequency')
plt.xlabel('Amotivation')
#plt.title('Histogram of Language Distribution')
plt.show()
# Bin=15
data1.hist(column='Amotivation',color='orange',edgecolor='black', linewidth=1, alpha=0.7, zorder=2,bins=15)
plt.grid(linestyle='--', alpha=0.3)

plt.show()

# Bin=25
data1.hist(column='Amotivation',color='orange',edgecolor='black', linewidth=1, alpha=0.7, zorder=2,bins=25)
plt.grid(linestyle='--', alpha=0.3)

plt.show()

# Bin=81
data1.hist(column='Amotivation',color='orange',edgecolor='black', linewidth=0.8, alpha=0.7, zorder=2,bins=81)
plt.grid(linestyle='--', alpha=0.3)

plt.show()

# %%
data1.hist(column='Amotivation',by='Wie häufig machen Sie in der Woche Sport?', color='orange',edgecolor='black', linewidth=1, alpha=0.7, zorder=2,bins=10)
plt.show()

# %%
data1.boxplot(column='Amotivation')
# Add labels and title
plt.ylabel('Values')
plt.title('Box Plot')

plt.show()

# %%
data1.boxplot(column='Amotivation', by='Wie häufig machen Sie in der Woche Sport?')
plt.show()

# %%
data1.boxplot(column='Motivation Score', by='Wie häufig machen Sie in der Woche Sport?')
plt.show()

data1.boxplot(column='Intrinsic Motivation', by='Wie häufig machen Sie in der Woche Sport?')
plt.show()

# %%
plt.scatter(data1['Wie häufig machen Sie in der Woche Sport?'], data1['Amotivation'], s=50, c='#9ACD32', edgecolor='black', marker='o')

# Add labels and title
plt.ylabel('Amotivation')
plt.title('Scatter Plot')

#labels = ['Language 1', 'Language 2', 'Language 3']
#plt.xticks(range(1, 4), labels)

# Show the plot
plt.show()

# %%
plt.scatter(data1['Wie häufig machen Sie in der Woche Sport?'], data['Motivation Score'], s=50, c='#9ACD32', edgecolor='black', marker='o')

# Add labels and title
plt.ylabel('motivation score')
plt.xlabel('Wie häufig machen Sie in der Woche Sport?')
plt.title('Scatter Plot')

#labels = ['Language 1', 'Language 2', 'Language 3']
#plt.xticks(range(1, 4), labels)

# Show the plot
plt.show()

plt.scatter(data1['Wie häufig machen Sie in der Woche Sport?'], data['Amotivation'], s=50, c='#9ACD32', edgecolor='black', marker='o')

# Add labels and title
plt.ylabel('Amotivation')
plt.xlabel('Wie häufig machen Sie in der Woche Sport?')
plt.title('Scatter Plot')

#labels = ['Language 1', 'Language 2', 'Language 3']
#plt.xticks(range(1, 4), labels)

# Show the plot
plt.show()


plt.scatter(data1['Wie häufig machen Sie in der Woche Sport?'], data['Intrinsic Motivation'], s=50, c='#9ACD32', edgecolor='black', marker='o')

# Add labels and title
plt.ylabel('Intrinsic Motivation')
plt.xlabel('Wie häufig machen Sie in der Woche Sport?')
plt.title('Scatter Plot')

#labels = ['Language 1', 'Language 2', 'Language 3']
#plt.xticks(range(1, 4), labels)

# Show the plot
plt.show()

plt.scatter(data['Ihr Alter in Jahren:'], data['Motivation Score'], s=50, c='#9ACD32', edgecolor='black', marker='o')

# Add labels and title
plt.ylabel('motivation score')
plt.title('Scatter Plot')
plt.xlabel('Age')
#labels = ['Language 1', 'Language 2', 'Language 3']
#plt.xticks(range(1, 4), labels)

# Show the plot
plt.show()
plt.scatter(data['Amotivation'], data['Intrinsic Motivation'], s=50, c='#9ACD32', edgecolor='black', marker='o')

# Add labels and title
plt.ylabel('Intrinsic Motivation')

plt.xlabel('Amotivation')
plt.title('Scatter Plot')

#labels = ['Language 1', 'Language 2', 'Language 3']
#plt.xticks(range(1, 4), labels)

# Show the plot
plt.show()
plt.scatter(data['Amotivation'], (data['Intrinsic Motivation']+data['Identified Regulation']+data['Introjected Regulation']+data['Integrated Regulation']+data['External Regulation'])/5, s=50, c='#9ACD32', edgecolor='black', marker='o')

# Add labels and title
plt.ylabel('alle motivation außer Amotivation')

plt.xlabel('Amotivation')
plt.title('Scatter Plot')

#labels = ['Language 1', 'Language 2', 'Language 3']
#plt.xticks(range(1, 4), labels)

# Show the plot
plt.show()

# %%
plt.scatter(data1['Wie oft benutzen Sie eine Sport-App?  '], data['Motivation Score'], s=50, c='#9ACD32', edgecolor='black', marker='o')

# Add labels and title
plt.ylabel('motivation score')
plt.xlabel('Wie oft benutzen Sie eine Sport App?')
plt.title('Scatter Plot')

#labels = ['Language 1', 'Language 2', 'Language 3']
#plt.xticks(range(1, 4), labels)

# Show the plot
plt.show()

# %%
plt.scatter(data['Geschlecht'], data['Motivation Score'], s=50, c='#9ACD32', edgecolor='black', marker='o')

# Add labels and title
plt.ylabel('motivation score')
plt.title('Scatter Plot')

#labels = ['Language 1', 'Language 2', 'Language 3']
#plt.xticks(range(1, 4), labels)

# Show the plot
plt.show()
plt.scatter(data['Haben Sie schonmal Sport-Apps genutzt? (Z.B. Apple Sports, Adidas Running App, Komoot, Nike Training Club, Freeletics, Urban Sports Club, Stava, etc.)  '], data['Motivation Score'], s=50, c='#9ACD32', edgecolor='black', marker='o')

# Add labels and title
plt.ylabel('motivation score')
plt.title('Scatter Plot')

#labels = ['Language 1', 'Language 2', 'Language 3']
#plt.xticks(range(1, 4), labels)

# Show the plot
plt.show()

# %%
# Language one
sm.qqplot(data=data1[data1['Wie häufig machen Sie in der Woche Sport?'] == '5-6 mal die Woche']['Amotivation'], line='s', markerfacecolor='#00FF7F', markeredgecolor='black')
plt.title('QQ Plot 5-6 mal die Woche Sport')
plt.show()

# Language two
sm.qqplot(data=data1[data1['Wie häufig machen Sie in der Woche Sport?'] == '3-4 mal die Woche']['Amotivation'], line='s', markerfacecolor='PowderBlue', markeredgecolor='black')
plt.title('QQ Plot 3-4 mal die Woche Sport')
plt.show()

# Language two
sm.qqplot(data=data1[data1['Wie häufig machen Sie in der Woche Sport?'] == '1-2 mal die Woche']['Amotivation'], line='s', markerfacecolor='#FFCCCC', markeredgecolor='black')
plt.title('QQ Plot 1-2 mal die Woche Sport')
plt.show()
# Language one
sm.qqplot(data1['Amotivation'], line='s', markerfacecolor='#00FF7F', markeredgecolor='black')

plt.show()
